# %%
import requests
from time import sleep

result = []

for i in range(1, 23):
    response = requests.get(f"http://localhost:8000?q={i}")
    response_data = response.json()
    print(i, response.status_code, response_data["elapsed"])
    result.append(response_data["elapsed"])
    sleep(1)
# Out:
# 1 200 0.3474486999984947
# 2 200 0.0822383999984595
# 3 200 0.6150287999989814
# 4 200 0.19575170000462094
# 5 200 0.33224820000032196
# 6 200 0.2966636000055587
# 7 200 0.4133025999981328
# 8 200 0.4215745999972569
# 9 200 0.5045616000061273
# 10 200 1.008464599995932
# 11 200 0.14335099999880185
# 12 200 0.306484000000637
# 13 200 0.36152369999763323
# 14 200 0.349668599999859
# 15 200 0.27645449999545235
# 16 200 0.23408940000081202
# 17 200 0.3205750999986776
# 18 200 0.41599549999955343
# 19 200 0.4600547000009101
# 20 200 0.335067899999558
# 21 200 0.6692949999996927
# 22 200 0.1691214000020409

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(1, len(result) + 1)

# result配列をプロット
plt.bar(x, result)
plt.xlabel('Request Index')
plt.ylabel('Elapsed Time')
plt.title('Elapsed Time for Each Request')
plt.xticks(x)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
